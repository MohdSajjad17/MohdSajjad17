# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSajjad17/MohdSajjad17/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
configparser==7.1.0
tableau_migration
python-dotenv==1.0.1
# Out:
#   File "<ipython-input-2-2a39045819d3>", line 1
#     configparser==7.1.0
#                      ^
# SyntaxError: invalid syntax
